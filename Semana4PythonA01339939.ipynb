# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-Ed9ar/blob/main/Semana4PythonA01339939.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Módulo 1 Data Analysis with Python IBM
#
# Edgar López Valdés A01339939
#
# Ciencia de datos

# %% [markdown]
# Problema del curso
# Estimar el precio de un auto a partir de sus caracteristicas.
# Los datos no necesariamente son informacion, la analitica de datos ayuda a desbloquear la info de un conjunto.
#
# Algunas preguntas
#
#
# ¿Color?
# ¿Marca? etc
#
# En el caso de este conjunto de datos (head) contiene datos tambien. Precio es el atributo a predecir. Los paquetes a utilizar son Pandas Numpy y
# Scipy. De pandas se utilizan principalmente los dataframes, numpy utiliza arreglos para entrada y salida u operaciones matriciales. Matplotlib es un apoyo para la visualizacion.

# %%
#Normalmente la informacion se presenta en csv, json, xlsx, etc. Se puede extraer del equipo local o simplemente desde la red.

# %% [markdown]
# Algunos de los métodos más comunes em pandas son:
#
# dtype para verificar el tipo de objeto
# se puede utilizar tambien count o mean, std o describe para obtener valores o información general de un conjunto de datos.
#
# Unique sirve para obtener el número de diferentes registros en una columna. Asi como freq nos da la frecuencia del primer registro
#
# Por último dataframe.info nos muestra los primeros y últimos 30 registros

# %%
#Lab 1

#Tuve problemas para correr las librerias de manera local por lo que adjunto imagen de los ejercicios en el laboratorio

# !pip install piplite
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ERROR: Could not find a version that satisfies the requirement piplite (from versions: none)
# ERROR: No matching distribution found for piplite

# %%
import piplite
import micropip
await piplite.install(['pandas'])
await piplite.install(['matplotlib'])
await piplite.install(['scipy'])
await piplite.install(['seaborn'])
await micropip.install(['ipywidgets'],keep_going=True)
await micropip.install(['tqdm'],keep_going=True)

# %%
import pandas as pd
import numpy as np

# %%
#Esta funcion nos ayuda a descargar el set de datos desde una URL
from pyodide.http import pyfetch

async def download(url, filename):
    response = await pyfetch(url)
    if response.status == 200:
        with open(filename, "wb") as f:
            f.write(await response.bytes())

# %%
path = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/auto.csv"
await download(path, "auto.csv")
path="auto.csv"
#con el path podemos obtener el conjunto de datos, visualizamos las primeras 5 filas de la siguiente manera

# %% [markdown]
# ![Screen Shot 2022-10-11 at 0.28.32.png](data:image/png;base64,...)

# %%
headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
print("headers\n", headers)

#la lista de headers nos permite añadir nombres a las columnas en este caso sustituir los números

# %%
#Soltamos los valores nulos
df1=df.replace('?',np.NaN)
df=df1.dropna(subset=["price"], axis=0)
df.head(20) 

#Visualizamos los primeros 20 registros sin valores nulos

# %% [markdown]
# ![Screen Shot 2022-10-11 at 0.30.12.png](data:image/png;base64,...)

# %%
#si queremos ver los tipos se utiliza 
df.dtypes

# %%
#El método describe nos da info estadistica de las columnas y se visualiza de la siguiente manera :

# %% [markdown]
# ![Screen Shot 2022-10-11 at 0.30.38.png](data:image/png;base64,...)

# %%
#Es posible seleccionar columnas especifícas para visualizar estos datos

# %% [markdown]
# ![Screen Shot 2022-10-11 at 0.30.53.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2022-10-11 at 0.31.04.png](data:image/png;base64,...)
