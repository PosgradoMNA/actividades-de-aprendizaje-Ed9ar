# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-Ed9ar/blob/main/Semana_5_Data_Analysis_with_Python_(IBM)A01339939.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Módulo 2 Data Analysis with Python
#
# ##Edgar López Valdés A01339939

# %% [markdown]
# Durante el preprocesamiento podemos realizar diversas técnicas de limpieza. Si se da el caso en el que tenemos valores nulos o faltantes podemos eliminarlos. Estos se representan con NaN (not a number). Es posible removerlos simplemente aunque siempre se busca que el impacto sea lo menor posible, por lo que se recomienda reemplazar datos con valores utilizables en vez de solo eliminarlos.
#
# Podríamos por ejemplo sustituir valores númericos faltantes por la media de la columna en cuestión.

# %%
'''
Si se busca normalizar los datos durante el preprocesamiento podríamos hacerlo
fácilmente con las funciones integradas de python

Al normalizar aseguramos que el rando de valores se mantenga consistente. 
Algunos métodos conocidos de normalización podrían ser Min-Max o standard score- Em estps se recalculan 
los valores a partir de un par
ámetro de normalización.
'''
# Out:
# '\nSi se busca normalizar los datos durante el preprocesamiento podríamos hacerlo fácilmente con las funciones integradas de python\n\nAl normalizar aseguramos que el rando de valores se mantenga consistente. Algunos métodos conocidos de normalización podrían ser Min-Max o standard score- Em estps se recalculan los valores a partir de un par\námetro de normalización.\n'

# %%
'''
Otro método de preprocesamiento es el binning. En este se establecen grupos a partir de valores númericos. 
En ocasiones se puede incrementar de manera significativa la precisión de los modelos con esta técnica. Un ejemplo,
sería categorizar los precios de autos en grupos por incrementos. Los divisores deben estar a la misma distancia unos de otros.

'''
# Out:
# '\nOtro método de preprocesamiento es el binning. En este se establecen grupos a partir de valores númericos. \nEn ocasiones se puede incrementar de manera significativa la precisión de los modelos con esta técnica. Un ejemplo,\nsería categorizar los precios de autos en grupos por incrementos. Los divisores deben estar a la misma distancia unos de otros.\n\n'

# %%
''' 
Durante el preprocesamiento también se pueden realizar ajustes como el transformar las variables categóricas en cuantitativas.
Si por ejemplo se tienen Strings de varibles tipo combustibles gas y diesel. Se establecen valores 1 y 0 dependiendo del caso para poder realizar análisis estadísticos de mejor manera.
'''
# Out:
# ' \nDurante el preprocesamiento también se pueden realizar ajustes como el transformar las variables categóricas en cuantitativas.\nSi por ejemplo se tienen Strings de varibles tipo combustibles gas y diesel. Se establecen valores 1 y 0 dependiendo del caso para poder realizar análisis estadísticos de mejor manera.\n'

# %%
#Lab
#If you run the lab locally using Anaconda, you can load the correct library and versions by uncommenting the following:
#install specific version of libraries used in lab
import pandas as pd
import matplotlib.pylab as plt

#Se lee el archivo desde una url remota

# %% [markdown]
# ![Captura de Pantalla 2022-10-15 a la(s) 13.09.31.png](data:image/png;base64,...)

# %%
#Reemplazamos los valores ? con NaN y determinamos que columnas tienen valores vacios

# %% [markdown]
# ![Captura de Pantalla 2022-10-15 a la(s) 13.12.29.png](data:image/png;base64,...)

# %%
#Se reemplazan los valores vacios de la columna normalized-losses por la media

# %% [markdown]
# ![Captura de Pantalla 2022-10-15 a la(s) 13.14.00.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de Pantalla 2022-10-15 a la(s) 13.14.35.png](data:image/png;base64,...)

# %%
#Al ver de nuevo los valores de columnas modificadas vemos que hay cambios, ya no hay valores vacios ya que se hicieron sustituciones y en el caso de precios se elimina la fila completa si es que no tienen nada

# %% [markdown]
# ![Captura de Pantalla 2022-10-15 a la(s) 13.14.58.png](data:image/png;base64,...)

# %%
#Verificamos los tipos de datos, previo a realizar conversiones

# %% [markdown]
# ![Captura de Pantalla 2022-10-15 a la(s) 13.15.12.png](data:image/png;base64,...)

# %%
#Verificamos que se hayan hecho los cambios a los tipos de datos

# %% [markdown]
# ![Captura de Pantalla 2022-10-15 a la(s) 13.16.05.png](data:image/png;base64,...)

# %%
#Estandarizamos unidades con la formula que se proporciona en el ejercicio

# %% [markdown]
# ![Captura de Pantalla 2022-10-15 a la(s) 13.16.16.png](data:image/png;base64,...)

# %%
#Despues se normaliza para mantener los valores en un mismo rango

# %% [markdown]
# ![Captura de Pantalla 2022-10-15 a la(s) 13.16.39.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de Pantalla 2022-10-15 a la(s) 13.16.55.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de Pantalla 2022-10-15 a la(s) 13.16.58.png](data:image/png;base64,...)

# %%
#Se separan los datos por grupos despues de realizar binning y contar los valores obtenemos las siguientes graficas

# %% [markdown]
# ![Captura de Pantalla 2022-10-15 a la(s) 13.17.02.png](data:image/png;base64,...)

# %%
#Si quisieramos trabajar con variables categoricas como el combustible es necesario volverlas cuantitativas primero

# %% [markdown]
# ![Captura de Pantalla 2022-10-15 a la(s) 13.17.46.png](data:image/png;base64,...)

# %%
#Podemos asignar los valores dummies en estas columnas para obtener clasificacines numericas y finalmente agregarlas al conjunto original

# %% [markdown]
# ![Captura de Pantalla 2022-10-15 a la(s) 13.18.25.png](data:image/png;base64,...)

# %%
'''
Preguntas finales
'''

# %% [markdown]
# ![Captura de Pantalla 2022-10-15 a la(s) 13.38.56.png](data:image/png;base64,...)![Captura de Pantalla 2022-10-15 a la(s) 13.39.42.png](data:image/png;base64,...)![Captura de Pantalla 2022-10-15 a la(s) 13.38.17.png](data:image/png;base64,...)
