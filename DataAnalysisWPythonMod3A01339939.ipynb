# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-Ed9ar/blob/main/DataAnalysisWPythonMod3A01339939.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Módulo 3 Data Analysis with Python IBM
#
# Edgar López Valdés A01339939
#
# Ciencia de datos

# %%
#El análisis exploratorio de datos es un acercamiento para resumir las caracteristicas de los datos.

'''
De cierta manera se busca encontrar los componentes que más afectan.

Por un lado la estatística descriptiva nos entrega información de valores importantes

Con pandas se puede utilizar la función describe()

Se puede utilizar también un boxplot para determinar los valores outliers y las distribuciones.

Otra recomendación se puede utilizar las funciones de agrupamiento para transformar el conjunto de datos, puede ser que encontremos relaciones
en los diferentes atributos o valor sobre los relacionados. Esto es sumamente útil para determinar altos y bajos valores que impacten
en el valor final.

Uno de los valores de mayor importancia que podemos determinar es la correlación de varibles, esta nos da una explicación de como impacta una variable en otra. Un ejemplo es si las personas l
llevan sombrillas cuando hay lluvia. Correlación no significa causalidad.
'''
# Out:
# '\nDe cierta manera se busca encontrar los componentes que más afectan.\n\nPor un lado la estatística descriptiva nos entrega información de valores importantes\n\nCon pandas se puede utilizar la función describe()\n\nSe puede utilizar también un boxplot para determinar los valores outliers y las distribuciones.\n\nOtra recomendación se puede utilizar las funciones de agrupamiento para transformar el conjunto de datos, puede ser que encontremos relaciones\nen los diferentes atributos o valor sobre los relacionados. Esto es sumamente útil para determinar altos y bajos valores que impacten\nen el valor final.\n\nUno de los valores de mayor importancia que podemos determinar es la correlación de varibles, esta nos da una explicación de como impacta una variable en otra. Un ejemplo es si las personas l\nllevan sombrillas cuando hay lluvia. Correlación no significa causalidad.\n'

# %%
#Lab

# %% [markdown]
# Obtenemos el conjunto de datos desde una URL remota

# %% [markdown]
# ![Captura de Pantalla 2022-10-21 a la(s) 10.35.59.png](data:image/png;base64,...)

# %% [markdown]
# Podemo analizar los tipos de datos y posteriormente visualizar la matriz de correlación para entender la relación de las variables.

# %% [markdown]
# ![Captura de Pantalla 2022-10-21 a la(s) 10.36.23.png](data:image/png;base64,...)

# %% [markdown]
# Visualmente es posible entender también si la relación es positiva o negativa. Además de que tan fuerte es.

# %% [markdown]
# ![Captura de Pantalla 2022-10-21 a la(s) 10.36.42.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de Pantalla 2022-10-21 a la(s) 10.36.52.png](data:image/png;base64,...)

# %% [markdown]
# En este caso vemos que es muy débil entre peak-rpm y precio

# %% [markdown]
# ![Captura de Pantalla 2022-10-21 a la(s) 10.37.12.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de Pantalla 2022-10-21 a la(s) 10.37.31.png](data:image/png;base64,...)

# %% [markdown]
# Por otra parte es posible realizar el análisis descriptivo

# %% [markdown]
# ![Captura de Pantalla 2022-10-21 a la(s) 10.37.54.png](data:image/png;base64,...)

# %% [markdown]
# Cuando se empieza a agrupar por características como precio o tipos, para obtener los promedios.

# %% [markdown]
# ![Captura de Pantalla 2022-10-21 a la(s) 10.38.02.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de Pantalla 2022-10-21 a la(s) 10.38.58.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de Pantalla 2022-10-21 a la(s) 10.39.05.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de Pantalla 2022-10-21 a la(s) 10.39.10.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de Pantalla 2022-10-21 a la(s) 10.39.15.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de Pantalla 2022-10-21 a la(s) 10.39.20.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de Pantalla 2022-10-21 a la(s) 10.39.25.png](data:image/png;base64,...)

# %% [markdown]
# Graded Questions

# %% [markdown]
# ![Captura de Pantalla 2022-10-21 a la(s) 10.53.01.png](data:image/png;base64,...)

# %% [markdown]
# ![Captura de Pantalla 2022-10-21 a la(s) 10.53.28.png](data:image/png;base64,...)
